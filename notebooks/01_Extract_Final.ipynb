# %% [markdown]
# # Extract and Transform data

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import requests
import os
from dotenv import load_dotenv
import json

load_dotenv()
API_TOKEN = str(os.getenv('API_TOKEN'))

# %% [markdown]
# ## Extract data from the Million Playlist Dataset

# %%
def read_json_file(file_path: str=None, url: str=None) -> dict:
    """
    This function reads a json file from a local path or from a url.


    :param file_path: Path to the json file.
    :param url: Url to the json file.

    :return: A dictionary with the json file content.    
    """

    if url is not None:
        response = requests.get(url)
        data = response.json()
        return data

    elif file_path is not None:
        with open(file_path, 'r') as json_file:
            data = json.load(json_file)
            return data
        

def extract_content_from_json(data: dict) -> pd.DataFrame:
    """
    This function extracts the content from a json file and returns a dataframe.

    :param data: A dictionary with the json file content.

    :return: A dataframe with the json file content.
    """
    df_musics = pd.DataFrame()

    # Iterating over playlists
    for playlist in data['playlists']:
        name_playlist = playlist['name']
        id_playlist = playlist['pid']

        print(f'{id_playlist} - Playlist: {name_playlist}')

        # Iterating over the songs in the playlist
        musics_playlist = playlist['tracks']

        for music in musics_playlist:
            # name_musica = music['track_name']
            # id_musica = music['track_uri']

            # print(f'\tSong: {name_song} - ID: {song_id}')
            df_musica_aux = pd.DataFrame.from_dict(music, orient='index')
            df_musica_aux = df_musica_aux.T

            # Add the playlist name and playlist ID
            df_musica_aux['playlist_name'] = name_playlist
            df_musica_aux['playlist_id'] = id_playlist

            df_musica_aux = df_musica_aux.T
            df_musics = pd.concat([df_musics, df_musica_aux], axis=1)

    return df_musics

# %%
# For each playlist file, extract the content and save it in a csv file

files_used = [
    'mpd.slice.0-999.json',
    'mpd.slice.1000-1999.json',
    'mpd.slice.2000-2999.json',
    # 'mpd.slice.3000-3999.json', #TODO
    'mpd.slice.4000-4999.json',
    'mpd.slice.5000-5999.json',
]

# %%
for file in files_used:
    version = file.split('.')[2].replace('-', '_')

    data = read_json_file(file_path=f'../data/00 - Raw Data/{file}')
    df_musics = extract_content_from_json(data)
    df_musics.to_csv(f'../data/01 - Extracted Data/df_musics_{version}.csv', index=False)

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Concatenate all the dataframes into one

# %%
df_musics_final = pd.DataFrame()

for file in files_used:
    version = file.split('.')[2].replace('-', '_')

    df = pd.read_csv(f'../data/01 - Extracted Data/df_musics_{version}.csv')

    # Keep only the columns that we need
    df = df[['track_uri', 'artist_uri', 'album_uri']]

    # Concatenate the dataframes
    df_musics_final = pd.concat([df_musics_final, df], axis=0)

# Remove duplicates
df_musics_final.drop_duplicates(inplace=True)

# Save the final dataframe
df_musics_final.to_csv('../data/01 - Extracted Data/df_musics_concatenate.csv', index=False)

df_musics_final.head(5)
# Out:
#                               track_uri  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H
#
#                               artist_uri                             album_uri
# 0  spotify:artist:2wIVse2owClT7go1WT98tk  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K
# 1  spotify:artist:26dSoYclwsYLMAKD3tpOr4  spotify:album:0z7pVBGOD7HCIB7S8eLkLI
# 2  spotify:artist:6vWDO969PvNqNYHIOW5v0m  spotify:album:25hVFAxTlDvXbx2X2QkUkE
# 3  spotify:artist:31TPClRtHm23RisEBtV3X7  spotify:album:6QPkyl04rXwTGlGlcYaRoW
# 4  spotify:artist:5EvFsr3kj42KNv97ZEnqij  spotify:album:6NmFmPX56pcLBOFMhIiKvF

# %% [markdown]
# ## Clean Data

# %%
df_musics_final['track_uri'] = df_musics_final['track_uri'].str.replace('spotify:track:', '')
df_musics_final['artist_uri'] = df_musics_final['artist_uri'].str.replace('spotify:artist:', '')
df_musics_final['album_uri'] = df_musics_final['album_uri'].str.replace('spotify:album:', '')

df_musics_final.head(5)
# Out:
#                 track_uri              artist_uri               album_uri
# 0  0UaMYEvWZi0ZqiDOoHU3YI  2wIVse2owClT7go1WT98tk  6vV5UrXcfyQD1wu4Qo2I9K
# 1  6I9VzXrHxO9rA9A5euc8Ak  26dSoYclwsYLMAKD3tpOr4  0z7pVBGOD7HCIB7S8eLkLI
# 2  0WqIKmW4BTrj3eJFmnCKMv  6vWDO969PvNqNYHIOW5v0m  25hVFAxTlDvXbx2X2QkUkE
# 3  1AWQoqb9bSvzTjaLralEkT  31TPClRtHm23RisEBtV3X7  6QPkyl04rXwTGlGlcYaRoW
# 4  1lzr43nnXAijIGYnCT8M8H  5EvFsr3kj42KNv97ZEnqij  6NmFmPX56pcLBOFMhIiKvF

# %% [markdown]
# ## Define functions to extract data from Spotify API

# %%
def make_req(route: str, id: str) -> requests.models.Response:
    url = f'https://api.spotify.com/v1/{route}/{id}'

    headers = {
        'Authorization': f'Bearer {API_TOKEN}'
    }

    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f'Erro: {response.status_code}')
        print(f'Erro: {response.json()}')
        import sys
        sys.exit(1)

    else:
        return response


def get_track(id_track: str) -> pd.DataFrame:
    data = make_req('tracks', id_track).json()
    df = pd.DataFrame(data['tracks'])
    return df


def get_audio_features(id_track: str) -> dict:
    data = make_req('audio-features', id_track).json()
    df = pd.DataFrame(data['audio_features'])
    return df


def get_album(id_album: str) -> dict:
    data = make_req('albums', id_album).json()
    df = pd.DataFrame(data['albums'])
    return df


def get_artist_data(id_artist: str) -> dict:
    data = make_req('artists', id_artist).json()
    df = pd.DataFrame(data['artists'])
    return df

# %%
def get_music_features(tracks_ids: list) -> dict:

    tracks_ids_str = ','.join(tracks_ids)
    tracks_ids_str = '?ids=' + tracks_ids_str

    # 1. Get track data
    tracks_list_df = get_track(tracks_ids_str)

    # Collect album ids
    tracks_list_df['id_album'] = tracks_list_df['album'].apply(lambda x: x['id'])

    # Collect artist ids
    tracks_list_df['id_artist'] = tracks_list_df['artists'].apply(lambda x: [d['id'] for d in x])

    # Expand artist ids to separate rows
    tracks_list_df = tracks_list_df.explode('id_artist')

    
    # 2. Get audio features
    df_audio_features = pd.DataFrame()
    for i in range(0, len(tracks_ids), 50):
        tracks_ids_str = ','.join(tracks_ids[i:i+50] )
        tracks_ids_str = '?ids=' + tracks_ids_str
        df_audio_features_aux = get_audio_features(tracks_ids_str)
        df_audio_features = pd.concat([df_audio_features, df_audio_features_aux], axis=0)

    # Filtering columns
    df_audio_features = df_audio_features[['id', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]
    
    # Merge audio features with track data
    tracks_list_df = tracks_list_df.merge(df_audio_features, on='id', how='left')


    # 3. Get album data
    df_albums = pd.DataFrame()
    albums_ids = tracks_list_df['id_album'].unique().tolist()
    for i in range(0, len(albums_ids), 20):
        albums_ids_str = ','.join(albums_ids[i:i+20] )
        albums_ids_str = '?ids=' + albums_ids_str
        df_albums_aux = get_album(albums_ids_str)
        df_albums = pd.concat([df_albums, df_albums_aux], axis=0)

    # Filtering columns
    df_albums = df_albums[['id', 'name', 'popularity', 'release_date', 'total_tracks', 'type']]

    # Rename columns
    df_albums = df_albums.rename(columns={'id': 'id_album', 'name': 'album_name', 'popularity': 'album_popularity', 'release_date': 'album_release_date', 'total_tracks': 'album_total_tracks', 'type': 'album_type'})

    # Merge album data with track data
    tracks_list_df = tracks_list_df.merge(df_albums, on='id_album', how='left')
    

    # 4. Get artist data
    df_artists = pd.DataFrame()
    artists_ids = tracks_list_df['id_artist'].unique().tolist()
    for i in range(0, len(artists_ids), 50):
        artists_ids_str = ','.join(artists_ids[i:i+50] )
        artists_ids_str = '?ids=' + artists_ids_str
        df_artists_aux = get_artist_data(artists_ids_str)
        df_artists = pd.concat([df_artists, df_artists_aux], axis=0)

    # Filtering columns
    df_artists = df_artists[['id', 'name', 'genres', 'popularity', 'type', 'followers']]

    # Rename columns
    df_artists = df_artists.rename(columns={'id': 'id_artist', 'name': 'artist_name', 'genres': 'artist_genres', 'popularity': 'artist_popularity', 'type': 'artist_type', 'followers': 'artist_followers'})

    # Merge artist data with track data
    tracks_list_df = tracks_list_df.merge(df_artists, on='id_artist', how='left')

    # Collect number os followers
    tracks_list_df['artist_followers'] = tracks_list_df['artist_followers'].apply(lambda x: x['total'])

    # Expand artist ids to separate rows
    tracks_list_df = tracks_list_df.explode('artist_genres')

    # Keep only relevant artist_genres
    relevant_artist_genres = ['pop', 'hip hop', 'r&b', 'rap', 'reggae', 'rock', 'punk', 'alternative']
    tracks_list_df = tracks_list_df[tracks_list_df['artist_genres'].isin(relevant_artist_genres)]

    tracks_list_df = tracks_list_df[[
        'id', 'id_album', 'id_artist', 'name', 'explicit', 'duration_ms', 'popularity', # Track data
        'acousticness', 'danceability', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence', # Audio features
        'album_name', 'album_popularity', 'album_release_date', 'album_total_tracks', 'album_type', # Album data
        'artist_name', 'artist_genres', 'artist_popularity', 'artist_type', 'artist_followers' # Artist data
        ]]

    return tracks_list_df

# %%
# For each music (row in df_music_final), get the features of that song

tracks_ids = df_musics_final['track_uri'].unique().tolist()

df_musics_features_final = pd.DataFrame()
print(f'There are {len(tracks_ids)} tracks to be processed')

for i in range(0, len(tracks_ids), 50):
    print(f'Processing tracks {i} to {i+50}')
    try:
        df_aux = get_music_features(tracks_ids[i:i+50])
        df_musics_features_final = pd.concat([df_musics_features_final, df_aux], axis=0)
    except:
        print(f'Error processing tracks {i} to {i+50}')
        continue

df_musics_features_final.to_csv('../data/01 - Extracted Data/df_musics_features_final.csv', index=False)
# Out:
# There are 108181 tracks to be processed
# Processing tracks 0 to 50
# Processing tracks 50 to 100
# Processing tracks 100 to 150
# Processing tracks 150 to 200
# Processing tracks 200 to 250
# Processing tracks 250 to 300
# Processing tracks 300 to 350
# Processing tracks 350 to 400
# Processing tracks 400 to 450
# Processing tracks 450 to 500
# Processing tracks 500 to 550
# Processing tracks 550 to 600
# Processing tracks 600 to 650
# Processing tracks 650 to 700
# Processing tracks 700 to 750
# Processing tracks 750 to 800
# Processing tracks 800 to 850
# Processing tracks 850 to 900
# Processing tracks 900 to 950
# Processing tracks 950 to 1000
# Processing tracks 1000 to 1050
# Processing tracks 1050 to 1100
# Processing tracks 1100 to 1150
# Processing tracks 1150 to 1200
# Processing tracks 1200 to 1250
# Processing tracks 1250 to 1300
# Processing tracks 1300 to 1350
# Processing tracks 1350 to 1400
# Processing tracks 1400 to 1450
# Processing tracks 1450 to 1500
# Processing tracks 1500 to 1550
# Processing tracks 1550 to 1600
# Processing tracks 1600 to 1650
# Processing tracks 1650 to 1700
# Processing tracks 1700 to 1750
# Processing tracks 1750 to 1800
# Processing tracks 1800 to 1850
# Processing tracks 1850 to 1900
# Processing tracks 1900 to 1950
# Processing tracks 1950 to 2000
# Processing tracks 2000 to 2050
# Processing tracks 2050 to 2100
# Processing tracks 2100 to 2150
# Processing tracks 2150 to 2200
# Processing tracks 2200 to 2250
# Processing tracks 2250 to 2300
# Processing tracks 2300 to 2350
# Processing tracks 2350 to 2400
# Processing tracks 2400 to 2450
# Processing tracks 2450 to 2500
# Processing tracks 2500 to 2550
# Processing tracks 2550 to 2600
# Processing tracks 2600 to 2650
# Processing tracks 2650 to 2700
# Processing tracks 2700 to 2750
# Processing tracks 2750 to 2800
# Processing tracks 2800 to 2850
# Processing tracks 2850 to 2900
# Processing tracks 2900 to 2950
# Processing tracks 2950 to 3000
# Processing tracks 3000 to 3050
# Processing tracks 3050 to 3100
# Processing tracks 3100 to 3150
# Processing tracks 3150 to 3200
# Processing tracks 3200 to 3250
# Processing tracks 3250 to 3300
# Processing tracks 3300 to 3350
# Processing tracks 3350 to 3400
# Processing tracks 3400 to 3450
# Processing tracks 3450 to 3500
# Processing tracks 3500 to 3550
# Processing tracks 3550 to 3600
# Processing tracks 3600 to 3650
# Processing tracks 3650 to 3700
# Processing tracks 3700 to 3750
# Processing tracks 3750 to 3800
# Processing tracks 3800 to 3850
# Processing tracks 3850 to 3900
# Processing tracks 3900 to 3950
# Processing tracks 3950 to 4000
# Processing tracks 4000 to 4050
# Processing tracks 4050 to 4100
# Processing tracks 4100 to 4150
# Processing tracks 4150 to 4200
# Processing tracks 4200 to 4250
# Processing tracks 4250 to 4300
# Processing tracks 4300 to 4350
# Processing tracks 4350 to 4400
# Processing tracks 4400 to 4450
# Processing tracks 4450 to 4500
# Processing tracks 4500 to 4550
# Processing tracks 4550 to 4600
# Processing tracks 4600 to 4650
# Processing tracks 4650 to 4700
# Processing tracks 4700 to 4750
# Processing tracks 4750 to 4800
# Processing tracks 4800 to 4850
# Processing tracks 4850 to 4900
# Processing tracks 4900 to 4950
# Processing tracks 4950 to 5000
# Processing tracks 5000 to 5050
# Processing tracks 5050 to 5100
# Processing tracks 5100 to 5150
# Processing tracks 5150 to 5200
# Processing tracks 5200 to 5250
# Processing tracks 5250 to 5300
# Processing tracks 5300 to 5350
# Processing tracks 5350 to 5400
# Processing tracks 5400 to 5450
# Processing tracks 5450 to 5500
# Processing tracks 5500 to 5550
# Processing tracks 5550 to 5600
# Processing tracks 5600 to 5650
# Processing tracks 5650 to 5700
# Processing tracks 5700 to 5750
# Processing tracks 5750 to 5800
# Processing tracks 5800 to 5850
# Processing tracks 5850 to 5900
# Processing tracks 5900 to 5950
# Processing tracks 5950 to 6000
# Processing tracks 6000 to 6050
# Processing tracks 6050 to 6100
# Processing tracks 6100 to 6150
# Processing tracks 6150 to 6200
# Processing tracks 6200 to 6250
# Processing tracks 6250 to 6300
# Processing tracks 6300 to 6350
# Processing tracks 6350 to 6400
# Processing tracks 6400 to 6450
# Processing tracks 6450 to 6500
# Processing tracks 6500 to 6550
# Processing tracks 6550 to 6600
# Processing tracks 6600 to 6650
# Processing tracks 6650 to 6700
# Processing tracks 6700 to 6750
# Processing tracks 6750 to 6800
# Processing tracks 6800 to 6850
# Processing tracks 6850 to 6900
# Processing tracks 6900 to 6950
# Processing tracks 6950 to 7000
# Processing tracks 7000 to 7050
# Processing tracks 7050 to 7100
# Processing tracks 7100 to 7150
# Processing tracks 7150 to 7200
# Processing tracks 7200 to 7250
# Processing tracks 7250 to 7300
# Processing tracks 7300 to 7350
# Processing tracks 7350 to 7400
# Processing tracks 7400 to 7450
# Processing tracks 7450 to 7500
# Processing tracks 7500 to 7550
# Processing tracks 7550 to 7600
# Processing tracks 7600 to 7650
# Processing tracks 7650 to 7700
# Processing tracks 7700 to 7750
# Processing tracks 7750 to 7800
# Processing tracks 7800 to 7850
# Processing tracks 7850 to 7900
# Processing tracks 7900 to 7950
# Processing tracks 7950 to 8000
# Processing tracks 8000 to 8050
# Processing tracks 8050 to 8100
# Processing tracks 8100 to 8150
# Processing tracks 8150 to 8200
# Processing tracks 8200 to 8250
# Processing tracks 8250 to 8300
# Processing tracks 8300 to 8350
# Processing tracks 8350 to 8400
# Processing tracks 8400 to 8450
# Processing tracks 8450 to 8500
# Processing tracks 8500 to 8550
# Processing tracks 8550 to 8600
# Processing tracks 8600 to 8650
# Processing tracks 8650 to 8700
# Processing tracks 8700 to 8750
# Processing tracks 8750 to 8800
# Processing tracks 8800 to 8850
# Processing tracks 8850 to 8900
# Processing tracks 8900 to 8950
# Processing tracks 8950 to 9000
# Processing tracks 9000 to 9050
# Processing tracks 9050 to 9100
# Processing tracks 9100 to 9150
# Processing tracks 9150 to 9200
# Processing tracks 9200 to 9250
# Processing tracks 9250 to 9300
# Processing tracks 9300 to 9350
# Processing tracks 9350 to 9400
# Processing tracks 9400 to 9450
# Processing tracks 9450 to 9500
# Processing tracks 9500 to 9550
# Processing tracks 9550 to 9600
# Processing tracks 9600 to 9650
# Processing tracks 9650 to 9700
# Processing tracks 9700 to 9750
# Processing tracks 9750 to 9800
# Processing tracks 9800 to 9850
# Processing tracks 9850 to 9900
# Processing tracks 9900 to 9950
# Processing tracks 9950 to 10000
# Processing tracks 10000 to 10050
# Processing tracks 10050 to 10100
# Processing tracks 10100 to 10150
# Processing tracks 10150 to 10200
# Processing tracks 10200 to 10250
# Processing tracks 10250 to 10300
# Processing tracks 10300 to 10350
# Processing tracks 10350 to 10400
# Processing tracks 10400 to 10450
# Processing tracks 10450 to 10500
# Processing tracks 10500 to 10550
# Processing tracks 10550 to 10600
# Processing tracks 10600 to 10650
# Processing tracks 10650 to 10700
# Processing tracks 10700 to 10750
# Processing tracks 10750 to 10800
# Processing tracks 10800 to 10850
# Processing tracks 10850 to 10900
# Processing tracks 10900 to 10950
# Processing tracks 10950 to 11000
# Processing tracks 11000 to 11050
# Processing tracks 11050 to 11100
# Processing tracks 11100 to 11150
# Processing tracks 11150 to 11200
# Processing tracks 11200 to 11250
# Processing tracks 11250 to 11300
# Processing tracks 11300 to 11350
# Processing tracks 11350 to 11400
# Processing tracks 11400 to 11450
# Processing tracks 11450 to 11500
# Processing tracks 11500 to 11550
# Processing tracks 11550 to 11600
# Processing tracks 11600 to 11650
# Processing tracks 11650 to 11700
# Processing tracks 11700 to 11750
# Processing tracks 11750 to 11800
# Processing tracks 11800 to 11850
# Processing tracks 11850 to 11900
# Processing tracks 11900 to 11950
# Processing tracks 11950 to 12000
# Processing tracks 12000 to 12050
# Processing tracks 12050 to 12100
# Processing tracks 12100 to 12150
# Processing tracks 12150 to 12200
# Processing tracks 12200 to 12250
# Processing tracks 12250 to 12300
# Processing tracks 12300 to 12350
# Processing tracks 12350 to 12400
# Processing tracks 12400 to 12450
# Processing tracks 12450 to 12500
# Processing tracks 12500 to 12550
# Processing tracks 12550 to 12600
# Processing tracks 12600 to 12650
# Processing tracks 12650 to 12700
# Processing tracks 12700 to 12750
# Processing tracks 12750 to 12800
# Processing tracks 12800 to 12850
# Processing tracks 12850 to 12900
# Processing tracks 12900 to 12950
# Processing tracks 12950 to 13000
# Processing tracks 13000 to 13050
# Processing tracks 13050 to 13100
# Processing tracks 13100 to 13150
# Processing tracks 13150 to 13200
# Processing tracks 13200 to 13250
# Processing tracks 13250 to 13300
# Processing tracks 13300 to 13350
# Processing tracks 13350 to 13400
# Processing tracks 13400 to 13450
# Processing tracks 13450 to 13500
# Processing tracks 13500 to 13550
# Processing tracks 13550 to 13600
# Processing tracks 13600 to 13650
# Processing tracks 13650 to 13700
# Processing tracks 13700 to 13750
# Processing tracks 13750 to 13800
# Processing tracks 13800 to 13850
# Processing tracks 13850 to 13900
# Processing tracks 13900 to 13950
# Processing tracks 13950 to 14000
# Processing tracks 14000 to 14050
# Processing tracks 14050 to 14100
# Processing tracks 14100 to 14150
# Processing tracks 14150 to 14200
# Processing tracks 14200 to 14250
# Processing tracks 14250 to 14300
# Processing tracks 14300 to 14350
# Processing tracks 14350 to 14400
# Processing tracks 14400 to 14450
# Processing tracks 14450 to 14500
# Processing tracks 14500 to 14550
# Processing tracks 14550 to 14600
# Processing tracks 14600 to 14650
# Processing tracks 14650 to 14700
# Processing tracks 14700 to 14750
# Processing tracks 14750 to 14800
# Processing tracks 14800 to 14850
# Processing tracks 14850 to 14900
# Processing tracks 14900 to 14950
# Processing tracks 14950 to 15000
# Processing tracks 15000 to 15050
# Processing tracks 15050 to 15100
# Processing tracks 15100 to 15150
# Processing tracks 15150 to 15200
# Processing tracks 15200 to 15250
# Processing tracks 15250 to 15300
# Processing tracks 15300 to 15350
# Processing tracks 15350 to 15400
# Processing tracks 15400 to 15450
# Processing tracks 15450 to 15500
# Processing tracks 15500 to 15550
# Processing tracks 15550 to 15600
# Processing tracks 15600 to 15650
# Processing tracks 15650 to 15700
# Processing tracks 15700 to 15750
# Processing tracks 15750 to 15800
# Processing tracks 15800 to 15850
# Processing tracks 15850 to 15900
# Processing tracks 15900 to 15950
# Processing tracks 15950 to 16000
# Processing tracks 16000 to 16050
# Processing tracks 16050 to 16100
# Processing tracks 16100 to 16150
# Processing tracks 16150 to 16200
# Processing tracks 16200 to 16250
# Processing tracks 16250 to 16300
# Processing tracks 16300 to 16350
# Processing tracks 16350 to 16400
# Processing tracks 16400 to 16450
# Processing tracks 16450 to 16500
# Processing tracks 16500 to 16550
# Processing tracks 16550 to 16600
# Processing tracks 16600 to 16650
# Processing tracks 16650 to 16700
# Processing tracks 16700 to 16750
# Processing tracks 16750 to 16800
# Processing tracks 16800 to 16850
# Processing tracks 16850 to 16900
# Processing tracks 16900 to 16950
# Processing tracks 16950 to 17000
# Processing tracks 17000 to 17050
# Processing tracks 17050 to 17100
# Processing tracks 17100 to 17150
# Processing tracks 17150 to 17200
# Processing tracks 17200 to 17250
# Processing tracks 17250 to 17300
# Processing tracks 17300 to 17350
# Processing tracks 17350 to 17400
# Processing tracks 17400 to 17450
# Processing tracks 17450 to 17500
# Processing tracks 17500 to 17550
# Processing tracks 17550 to 17600
# Processing tracks 17600 to 17650
# Processing tracks 17650 to 17700
# Processing tracks 17700 to 17750
# Processing tracks 17750 to 17800
# Processing tracks 17800 to 17850
# Processing tracks 17850 to 17900
# Processing tracks 17900 to 17950
# Processing tracks 17950 to 18000
# Processing tracks 18000 to 18050
# Processing tracks 18050 to 18100
# Processing tracks 18100 to 18150
# Processing tracks 18150 to 18200
# Processing tracks 18200 to 18250
# Processing tracks 18250 to 18300
# Processing tracks 18300 to 18350
# Processing tracks 18350 to 18400
# Processing tracks 18400 to 18450
# Processing tracks 18450 to 18500
# Processing tracks 18500 to 18550
# Processing tracks 18550 to 18600
# Processing tracks 18600 to 18650
# Processing tracks 18650 to 18700
# Processing tracks 18700 to 18750
# Processing tracks 18750 to 18800
# Processing tracks 18800 to 18850
# Processing tracks 18850 to 18900
# Processing tracks 18900 to 18950
# Processing tracks 18950 to 19000
# Processing tracks 19000 to 19050
# Processing tracks 19050 to 19100
# Processing tracks 19100 to 19150
# Processing tracks 19150 to 19200
# Processing tracks 19200 to 19250
# Processing tracks 19250 to 19300
# Processing tracks 19300 to 19350
# Processing tracks 19350 to 19400
# Processing tracks 19400 to 19450
# Processing tracks 19450 to 19500
# Processing tracks 19500 to 19550
# Processing tracks 19550 to 19600
# Processing tracks 19600 to 19650
# Processing tracks 19650 to 19700
# Processing tracks 19700 to 19750
# Processing tracks 19750 to 19800
# Processing tracks 19800 to 19850
# Processing tracks 19850 to 19900
# Processing tracks 19900 to 19950
# Processing tracks 19950 to 20000
# Processing tracks 20000 to 20050
# Processing tracks 20050 to 20100
# Processing tracks 20100 to 20150
# Processing tracks 20150 to 20200
# Processing tracks 20200 to 20250
# Processing tracks 20250 to 20300
# Processing tracks 20300 to 20350
# Processing tracks 20350 to 20400
# Processing tracks 20400 to 20450
# Processing tracks 20450 to 20500
# Processing tracks 20500 to 20550
# Processing tracks 20550 to 20600
# Processing tracks 20600 to 20650
# Error processing tracks 20600 to 20650
# Processing tracks 20650 to 20700
# Processing tracks 20700 to 20750
# Processing tracks 20750 to 20800
# Processing tracks 20800 to 20850
# Processing tracks 20850 to 20900
# Processing tracks 20900 to 20950
# Processing tracks 20950 to 21000
# Processing tracks 21000 to 21050
# Processing tracks 21050 to 21100
# Processing tracks 21100 to 21150
# Processing tracks 21150 to 21200
# Processing tracks 21200 to 21250
# Processing tracks 21250 to 21300
# Processing tracks 21300 to 21350
# Processing tracks 21350 to 21400
# Processing tracks 21400 to 21450
# Processing tracks 21450 to 21500
# Processing tracks 21500 to 21550
# Processing tracks 21550 to 21600
# Processing tracks 21600 to 21650
# Processing tracks 21650 to 21700
# Processing tracks 21700 to 21750
# Processing tracks 21750 to 21800
# Processing tracks 21800 to 21850
# Processing tracks 21850 to 21900
# Processing tracks 21900 to 21950
# Processing tracks 21950 to 22000
# Processing tracks 22000 to 22050
# Processing tracks 22050 to 22100
# Processing tracks 22100 to 22150
# Processing tracks 22150 to 22200
# Processing tracks 22200 to 22250
# Processing tracks 22250 to 22300
# Processing tracks 22300 to 22350
# Processing tracks 22350 to 22400
# Processing tracks 22400 to 22450
# Processing tracks 22450 to 22500
# Processing tracks 22500 to 22550
# Processing tracks 22550 to 22600
# Processing tracks 22600 to 22650
# Processing tracks 22650 to 22700
# Processing tracks 22700 to 22750
# Processing tracks 22750 to 22800
# Processing tracks 22800 to 22850
# Processing tracks 22850 to 22900
# Processing tracks 22900 to 22950
# Processing tracks 22950 to 23000
# Processing tracks 23000 to 23050
# Processing tracks 23050 to 23100
# Processing tracks 23100 to 23150
# Processing tracks 23150 to 23200
# Processing tracks 23200 to 23250
# Processing tracks 23250 to 23300
# Processing tracks 23300 to 23350
# Processing tracks 23350 to 23400
# Processing tracks 23400 to 23450
# Processing tracks 23450 to 23500
# Processing tracks 23500 to 23550
# Processing tracks 23550 to 23600
# Processing tracks 23600 to 23650
# Processing tracks 23650 to 23700
# Processing tracks 23700 to 23750
# Processing tracks 23750 to 23800
# Processing tracks 23800 to 23850
# Processing tracks 23850 to 23900
# Processing tracks 23900 to 23950
# Processing tracks 23950 to 24000
# Processing tracks 24000 to 24050
# Processing tracks 24050 to 24100
# Processing tracks 24100 to 24150
# Processing tracks 24150 to 24200
# Processing tracks 24200 to 24250
# Processing tracks 24250 to 24300
# Processing tracks 24300 to 24350
# Processing tracks 24350 to 24400
# Processing tracks 24400 to 24450
# Processing tracks 24450 to 24500
# Processing tracks 24500 to 24550
# Processing tracks 24550 to 24600
# Processing tracks 24600 to 24650
# Processing tracks 24650 to 24700
# Processing tracks 24700 to 24750
# Processing tracks 24750 to 24800
# Processing tracks 24800 to 24850
# Processing tracks 24850 to 24900
# Processing tracks 24900 to 24950
# Processing tracks 24950 to 25000
# Processing tracks 25000 to 25050
# Processing tracks 25050 to 25100
# Processing tracks 25100 to 25150
# Processing tracks 25150 to 25200
# Processing tracks 25200 to 25250
# Processing tracks 25250 to 25300
# Processing tracks 25300 to 25350
# Processing tracks 25350 to 25400
# Processing tracks 25400 to 25450
# Processing tracks 25450 to 25500
# Processing tracks 25500 to 25550
# Processing tracks 25550 to 25600
# Processing tracks 25600 to 25650
# Processing tracks 25650 to 25700
# Processing tracks 25700 to 25750
# Processing tracks 25750 to 25800
# Processing tracks 25800 to 25850
# Processing tracks 25850 to 25900
# Processing tracks 25900 to 25950
# Processing tracks 25950 to 26000
# Processing tracks 26000 to 26050
# Processing tracks 26050 to 26100
# Processing tracks 26100 to 26150
# Processing tracks 26150 to 26200
# Processing tracks 26200 to 26250
# Processing tracks 26250 to 26300
# Processing tracks 26300 to 26350
# Processing tracks 26350 to 26400
# Processing tracks 26400 to 26450
# Processing tracks 26450 to 26500
# Processing tracks 26500 to 26550
# Processing tracks 26550 to 26600
# Processing tracks 26600 to 26650
# Processing tracks 26650 to 26700
# Processing tracks 26700 to 26750
# Processing tracks 26750 to 26800
# Processing tracks 26800 to 26850
# Processing tracks 26850 to 26900
# Processing tracks 26900 to 26950
# Processing tracks 26950 to 27000
# Processing tracks 27000 to 27050
# Processing tracks 27050 to 27100
# Processing tracks 27100 to 27150
# Processing tracks 27150 to 27200
# Processing tracks 27200 to 27250
# Processing tracks 27250 to 27300
# Processing tracks 27300 to 27350
# Processing tracks 27350 to 27400
# Processing tracks 27400 to 27450
# Processing tracks 27450 to 27500
# Processing tracks 27500 to 27550
# Processing tracks 27550 to 27600
# Processing tracks 27600 to 27650
# Processing tracks 27650 to 27700
# Processing tracks 27700 to 27750
# Processing tracks 27750 to 27800
# Processing tracks 27800 to 27850
# Processing tracks 27850 to 27900
# Processing tracks 27900 to 27950
# Processing tracks 27950 to 28000
# Processing tracks 28000 to 28050
# Processing tracks 28050 to 28100
# Processing tracks 28100 to 28150
# Processing tracks 28150 to 28200
# Processing tracks 28200 to 28250
# Processing tracks 28250 to 28300
# Processing tracks 28300 to 28350
# Processing tracks 28350 to 28400
# Processing tracks 28400 to 28450
# Processing tracks 28450 to 28500
# Processing tracks 28500 to 28550
# Processing tracks 28550 to 28600
# Processing tracks 28600 to 28650
# Processing tracks 28650 to 28700
# Processing tracks 28700 to 28750
# Processing tracks 28750 to 28800
# Processing tracks 28800 to 28850
# Error processing tracks 28800 to 28850
# Processing tracks 28850 to 28900
# Processing tracks 28900 to 28950
# Processing tracks 28950 to 29000
# Processing tracks 29000 to 29050
# Processing tracks 29050 to 29100
# Processing tracks 29100 to 29150
# Processing tracks 29150 to 29200
# Processing tracks 29200 to 29250
# Processing tracks 29250 to 29300
# Processing tracks 29300 to 29350
# Processing tracks 29350 to 29400
# Processing tracks 29400 to 29450
# Processing tracks 29450 to 29500
# Processing tracks 29500 to 29550
# Processing tracks 29550 to 29600
# Processing tracks 29600 to 29650
# Processing tracks 29650 to 29700
# Processing tracks 29700 to 29750
# Processing tracks 29750 to 29800
# Processing tracks 29800 to 29850
# Processing tracks 29850 to 29900
# Processing tracks 29900 to 29950
# Processing tracks 29950 to 30000
# Processing tracks 30000 to 30050
# Processing tracks 30050 to 30100
# Processing tracks 30100 to 30150
# Processing tracks 30150 to 30200
# Processing tracks 30200 to 30250
# Processing tracks 30250 to 30300
# Processing tracks 30300 to 30350
# Processing tracks 30350 to 30400
# Processing tracks 30400 to 30450
# Processing tracks 30450 to 30500
# Processing tracks 30500 to 30550
# Processing tracks 30550 to 30600
# Processing tracks 30600 to 30650
# Processing tracks 30650 to 30700
# Processing tracks 30700 to 30750
# Processing tracks 30750 to 30800
# Processing tracks 30800 to 30850
# Processing tracks 30850 to 30900
# Processing tracks 30900 to 30950
# Processing tracks 30950 to 31000
# Processing tracks 31000 to 31050
# Processing tracks 31050 to 31100
# Processing tracks 31100 to 31150
# Processing tracks 31150 to 31200
# Processing tracks 31200 to 31250
# Processing tracks 31250 to 31300
# Processing tracks 31300 to 31350
# Processing tracks 31350 to 31400
# Processing tracks 31400 to 31450
# Processing tracks 31450 to 31500
# Processing tracks 31500 to 31550
# Processing tracks 31550 to 31600
# Processing tracks 31600 to 31650
# Processing tracks 31650 to 31700
# Processing tracks 31700 to 31750
# Processing tracks 31750 to 31800
# Processing tracks 31800 to 31850
# Processing tracks 31850 to 31900
# Processing tracks 31900 to 31950
# Processing tracks 31950 to 32000
# Processing tracks 32000 to 32050
# Processing tracks 32050 to 32100
# Processing tracks 32100 to 32150
# Processing tracks 32150 to 32200
# Processing tracks 32200 to 32250
# Processing tracks 32250 to 32300
# Processing tracks 32300 to 32350
# Processing tracks 32350 to 32400
# Processing tracks 32400 to 32450
# Processing tracks 32450 to 32500
# Processing tracks 32500 to 32550
# Processing tracks 32550 to 32600
# Processing tracks 32600 to 32650
# Processing tracks 32650 to 32700
# Processing tracks 32700 to 32750
# Processing tracks 32750 to 32800
# Processing tracks 32800 to 32850
# Processing tracks 32850 to 32900
# Processing tracks 32900 to 32950
# Processing tracks 32950 to 33000
# Processing tracks 33000 to 33050
# Processing tracks 33050 to 33100
# Processing tracks 33100 to 33150
# Processing tracks 33150 to 33200
# Processing tracks 33200 to 33250
# Processing tracks 33250 to 33300
# Processing tracks 33300 to 33350
# Processing tracks 33350 to 33400
# Processing tracks 33400 to 33450
# Processing tracks 33450 to 33500
# Processing tracks 33500 to 33550
# Processing tracks 33550 to 33600
# Processing tracks 33600 to 33650
# Processing tracks 33650 to 33700
# Processing tracks 33700 to 33750
# Processing tracks 33750 to 33800
# Processing tracks 33800 to 33850
# Processing tracks 33850 to 33900
# Processing tracks 33900 to 33950
# Processing tracks 33950 to 34000
# Processing tracks 34000 to 34050
# Processing tracks 34050 to 34100
# Processing tracks 34100 to 34150
# Processing tracks 34150 to 34200
# Processing tracks 34200 to 34250
# Processing tracks 34250 to 34300
# Processing tracks 34300 to 34350
# Processing tracks 34350 to 34400
# Processing tracks 34400 to 34450
# Processing tracks 34450 to 34500
# Processing tracks 34500 to 34550
# Processing tracks 34550 to 34600
# Processing tracks 34600 to 34650
# Processing tracks 34650 to 34700
# Processing tracks 34700 to 34750
# Processing tracks 34750 to 34800
# Processing tracks 34800 to 34850
# Processing tracks 34850 to 34900
# Processing tracks 34900 to 34950
# Processing tracks 34950 to 35000
# Processing tracks 35000 to 35050
# Processing tracks 35050 to 35100
# Processing tracks 35100 to 35150
# Processing tracks 35150 to 35200
# Processing tracks 35200 to 35250
# Processing tracks 35250 to 35300
# Processing tracks 35300 to 35350
# Processing tracks 35350 to 35400
# Processing tracks 35400 to 35450
# Processing tracks 35450 to 35500
# Processing tracks 35500 to 35550
# Processing tracks 35550 to 35600
# Processing tracks 35600 to 35650
# Processing tracks 35650 to 35700
# Processing tracks 35700 to 35750
# Processing tracks 35750 to 35800
# Processing tracks 35800 to 35850
# Processing tracks 35850 to 35900
# Processing tracks 35900 to 35950
# Processing tracks 35950 to 36000
# Processing tracks 36000 to 36050
# Processing tracks 36050 to 36100
# Processing tracks 36100 to 36150
# Processing tracks 36150 to 36200
# Processing tracks 36200 to 36250
# Processing tracks 36250 to 36300
# Processing tracks 36300 to 36350
# Processing tracks 36350 to 36400
# Processing tracks 36400 to 36450
# Processing tracks 36450 to 36500
# Processing tracks 36500 to 36550
# Processing tracks 36550 to 36600
# Processing tracks 36600 to 36650
# Processing tracks 36650 to 36700
# Processing tracks 36700 to 36750
# Processing tracks 36750 to 36800
# Processing tracks 36800 to 36850
# Processing tracks 36850 to 36900
# Processing tracks 36900 to 36950
# Processing tracks 36950 to 37000
# Processing tracks 37000 to 37050
# Processing tracks 37050 to 37100
# Processing tracks 37100 to 37150
# Processing tracks 37150 to 37200
# Processing tracks 37200 to 37250
# Processing tracks 37250 to 37300
# Processing tracks 37300 to 37350
# Processing tracks 37350 to 37400
# Processing tracks 37400 to 37450
# Processing tracks 37450 to 37500
# Processing tracks 37500 to 37550
# Error processing tracks 37500 to 37550
# Processing tracks 37550 to 37600
# Processing tracks 37600 to 37650
# Processing tracks 37650 to 37700
# Processing tracks 37700 to 37750
# Processing tracks 37750 to 37800
# Processing tracks 37800 to 37850
# Processing tracks 37850 to 37900
# Processing tracks 37900 to 37950
# Processing tracks 37950 to 38000
# Processing tracks 38000 to 38050
# Processing tracks 38050 to 38100
# Processing tracks 38100 to 38150
# Processing tracks 38150 to 38200
# Processing tracks 38200 to 38250
# Processing tracks 38250 to 38300
# Processing tracks 38300 to 38350
# Processing tracks 38350 to 38400
# Processing tracks 38400 to 38450
# Processing tracks 38450 to 38500
# Processing tracks 38500 to 38550
# Processing tracks 38550 to 38600
# Processing tracks 38600 to 38650
# Processing tracks 38650 to 38700
# Processing tracks 38700 to 38750
# Error processing tracks 38700 to 38750
# Processing tracks 38750 to 38800
# Processing tracks 38800 to 38850
# Processing tracks 38850 to 38900
# Processing tracks 38900 to 38950
# Processing tracks 38950 to 39000
# Processing tracks 39000 to 39050
# Processing tracks 39050 to 39100
# Processing tracks 39100 to 39150
# Processing tracks 39150 to 39200
# Processing tracks 39200 to 39250
# Processing tracks 39250 to 39300
# Processing tracks 39300 to 39350
# Processing tracks 39350 to 39400
# Processing tracks 39400 to 39450
# Processing tracks 39450 to 39500
# Processing tracks 39500 to 39550
# Processing tracks 39550 to 39600
# Processing tracks 39600 to 39650
# Processing tracks 39650 to 39700
# Processing tracks 39700 to 39750
# Processing tracks 39750 to 39800
# Processing tracks 39800 to 39850
# Processing tracks 39850 to 39900
# Processing tracks 39900 to 39950
# Processing tracks 39950 to 40000
# Processing tracks 40000 to 40050
# Processing tracks 40050 to 40100
# Processing tracks 40100 to 40150
# Processing tracks 40150 to 40200
# Processing tracks 40200 to 40250
# Processing tracks 40250 to 40300
# Processing tracks 40300 to 40350
# Processing tracks 40350 to 40400
# Processing tracks 40400 to 40450
# Processing tracks 40450 to 40500
# Processing tracks 40500 to 40550
# Processing tracks 40550 to 40600
# Processing tracks 40600 to 40650
# Processing tracks 40650 to 40700
# Processing tracks 40700 to 40750
# Processing tracks 40750 to 40800
# Processing tracks 40800 to 40850
# Processing tracks 40850 to 40900
# Processing tracks 40900 to 40950
# Processing tracks 40950 to 41000
# Processing tracks 41000 to 41050
# Processing tracks 41050 to 41100
# Processing tracks 41100 to 41150
# Processing tracks 41150 to 41200
# Processing tracks 41200 to 41250
# Processing tracks 41250 to 41300
# Processing tracks 41300 to 41350
# Processing tracks 41350 to 41400
# Processing tracks 41400 to 41450
# Processing tracks 41450 to 41500
# Processing tracks 41500 to 41550
# Processing tracks 41550 to 41600
# Processing tracks 41600 to 41650
# Processing tracks 41650 to 41700
# Processing tracks 41700 to 41750
# Processing tracks 41750 to 41800
# Processing tracks 41800 to 41850
# Processing tracks 41850 to 41900
# Processing tracks 41900 to 41950
# Processing tracks 41950 to 42000
# Processing tracks 42000 to 42050
# Processing tracks 42050 to 42100
# Processing tracks 42100 to 42150
# Processing tracks 42150 to 42200
# Processing tracks 42200 to 42250
# Processing tracks 42250 to 42300
# Processing tracks 42300 to 42350
# Processing tracks 42350 to 42400
# Processing tracks 42400 to 42450
# Processing tracks 42450 to 42500
# Processing tracks 42500 to 42550
# Processing tracks 42550 to 42600
# Processing tracks 42600 to 42650
# Processing tracks 42650 to 42700
# Processing tracks 42700 to 42750
# Processing tracks 42750 to 42800
# Processing tracks 42800 to 42850
# Processing tracks 42850 to 42900
# Processing tracks 42900 to 42950
# Processing tracks 42950 to 43000
# Processing tracks 43000 to 43050
# Processing tracks 43050 to 43100
# Processing tracks 43100 to 43150
# Processing tracks 43150 to 43200
# Processing tracks 43200 to 43250
# Processing tracks 43250 to 43300
# Processing tracks 43300 to 43350
# Processing tracks 43350 to 43400
# Processing tracks 43400 to 43450
# Processing tracks 43450 to 43500
# Processing tracks 43500 to 43550
# Processing tracks 43550 to 43600
# Processing tracks 43600 to 43650
# Processing tracks 43650 to 43700
# Processing tracks 43700 to 43750
# Processing tracks 43750 to 43800
# Processing tracks 43800 to 43850
# Processing tracks 43850 to 43900
# Processing tracks 43900 to 43950
# Processing tracks 43950 to 44000
# Processing tracks 44000 to 44050
# Processing tracks 44050 to 44100
# Processing tracks 44100 to 44150
# Processing tracks 44150 to 44200
# Processing tracks 44200 to 44250
# Processing tracks 44250 to 44300
# Processing tracks 44300 to 44350
# Processing tracks 44350 to 44400
# Processing tracks 44400 to 44450
# Processing tracks 44450 to 44500
# Processing tracks 44500 to 44550
# Processing tracks 44550 to 44600
# Processing tracks 44600 to 44650
# Processing tracks 44650 to 44700
# Processing tracks 44700 to 44750
# Processing tracks 44750 to 44800
# Processing tracks 44800 to 44850
# Processing tracks 44850 to 44900
# Processing tracks 44900 to 44950
# Processing tracks 44950 to 45000
# Processing tracks 45000 to 45050
# Processing tracks 45050 to 45100
# Processing tracks 45100 to 45150
# Processing tracks 45150 to 45200
# Processing tracks 45200 to 45250
# Processing tracks 45250 to 45300
# Processing tracks 45300 to 45350
# Processing tracks 45350 to 45400
# Processing tracks 45400 to 45450
# Processing tracks 45450 to 45500
# Processing tracks 45500 to 45550
# Processing tracks 45550 to 45600
# Processing tracks 45600 to 45650
# Processing tracks 45650 to 45700
# Processing tracks 45700 to 45750
# Processing tracks 45750 to 45800
# Processing tracks 45800 to 45850
# Processing tracks 45850 to 45900
# Processing tracks 45900 to 45950
# Processing tracks 45950 to 46000
# Processing tracks 46000 to 46050
# Processing tracks 46050 to 46100
# Processing tracks 46100 to 46150
# Processing tracks 46150 to 46200
# Processing tracks 46200 to 46250
# Processing tracks 46250 to 46300
# Processing tracks 46300 to 46350
# Processing tracks 46350 to 46400
# Processing tracks 46400 to 46450
# Processing tracks 46450 to 46500
# Processing tracks 46500 to 46550
# Processing tracks 46550 to 46600
# Processing tracks 46600 to 46650
# Processing tracks 46650 to 46700
# Processing tracks 46700 to 46750
# Processing tracks 46750 to 46800
# Processing tracks 46800 to 46850
# Processing tracks 46850 to 46900
# Processing tracks 46900 to 46950
# Processing tracks 46950 to 47000
# Processing tracks 47000 to 47050
# Processing tracks 47050 to 47100
# Processing tracks 47100 to 47150
# Processing tracks 47150 to 47200
# Processing tracks 47200 to 47250
# Processing tracks 47250 to 47300
# Processing tracks 47300 to 47350
# Processing tracks 47350 to 47400
# Processing tracks 47400 to 47450
# Processing tracks 47450 to 47500
# Processing tracks 47500 to 47550
# Processing tracks 47550 to 47600
# Processing tracks 47600 to 47650
# Processing tracks 47650 to 47700
# Processing tracks 47700 to 47750
# Processing tracks 47750 to 47800
# Processing tracks 47800 to 47850
# Processing tracks 47850 to 47900
# Processing tracks 47900 to 47950
# Processing tracks 47950 to 48000
# Processing tracks 48000 to 48050
# Processing tracks 48050 to 48100
# Processing tracks 48100 to 48150
# Processing tracks 48150 to 48200
# Processing tracks 48200 to 48250
# Processing tracks 48250 to 48300
# Processing tracks 48300 to 48350
# Processing tracks 48350 to 48400
# Processing tracks 48400 to 48450
# Processing tracks 48450 to 48500
# Processing tracks 48500 to 48550
# Processing tracks 48550 to 48600
# Processing tracks 48600 to 48650
# Processing tracks 48650 to 48700
# Processing tracks 48700 to 48750
# Processing tracks 48750 to 48800
# Processing tracks 48800 to 48850
# Processing tracks 48850 to 48900
# Processing tracks 48900 to 48950
# Processing tracks 48950 to 49000
# Processing tracks 49000 to 49050
# Processing tracks 49050 to 49100
# Processing tracks 49100 to 49150
# Processing tracks 49150 to 49200
# Processing tracks 49200 to 49250
# Processing tracks 49250 to 49300
# Processing tracks 49300 to 49350
# Processing tracks 49350 to 49400
# Processing tracks 49400 to 49450
# Processing tracks 49450 to 49500
# Processing tracks 49500 to 49550
# Processing tracks 49550 to 49600
# Processing tracks 49600 to 49650
# Processing tracks 49650 to 49700
# Processing tracks 49700 to 49750
# Processing tracks 49750 to 49800
# Processing tracks 49800 to 49850
# Processing tracks 49850 to 49900
# Processing tracks 49900 to 49950
# Processing tracks 49950 to 50000
# Processing tracks 50000 to 50050
# Processing tracks 50050 to 50100
# Processing tracks 50100 to 50150
# Processing tracks 50150 to 50200
# Processing tracks 50200 to 50250
# Processing tracks 50250 to 50300
# Processing tracks 50300 to 50350
# Processing tracks 50350 to 50400
# Processing tracks 50400 to 50450
# Processing tracks 50450 to 50500
# Processing tracks 50500 to 50550
# Processing tracks 50550 to 50600
# Processing tracks 50600 to 50650
# Processing tracks 50650 to 50700
# Processing tracks 50700 to 50750
# Processing tracks 50750 to 50800
# Processing tracks 50800 to 50850
# Processing tracks 50850 to 50900
# Processing tracks 50900 to 50950
# Processing tracks 50950 to 51000
# Processing tracks 51000 to 51050
# Processing tracks 51050 to 51100
# Processing tracks 51100 to 51150
# Processing tracks 51150 to 51200
# Processing tracks 51200 to 51250
# Processing tracks 51250 to 51300
# Processing tracks 51300 to 51350
# Processing tracks 51350 to 51400
# Processing tracks 51400 to 51450
# Processing tracks 51450 to 51500
# Processing tracks 51500 to 51550
# Processing tracks 51550 to 51600
# Processing tracks 51600 to 51650
# Processing tracks 51650 to 51700
# Processing tracks 51700 to 51750
# Processing tracks 51750 to 51800
# Processing tracks 51800 to 51850
# Processing tracks 51850 to 51900
# Processing tracks 51900 to 51950
# Processing tracks 51950 to 52000
# Processing tracks 52000 to 52050
# Processing tracks 52050 to 52100
# Processing tracks 52100 to 52150
# Processing tracks 52150 to 52200
# Processing tracks 52200 to 52250
# Processing tracks 52250 to 52300
# Processing tracks 52300 to 52350
# Processing tracks 52350 to 52400
# Processing tracks 52400 to 52450
# Processing tracks 52450 to 52500
# Processing tracks 52500 to 52550
# Processing tracks 52550 to 52600
# Processing tracks 52600 to 52650
# Processing tracks 52650 to 52700
# Processing tracks 52700 to 52750
# Processing tracks 52750 to 52800
# Processing tracks 52800 to 52850
# Processing tracks 52850 to 52900
# Processing tracks 52900 to 52950
# Processing tracks 52950 to 53000
# Processing tracks 53000 to 53050
# Processing tracks 53050 to 53100
# Processing tracks 53100 to 53150
# Processing tracks 53150 to 53200
# Processing tracks 53200 to 53250
# Processing tracks 53250 to 53300
# Processing tracks 53300 to 53350
# Processing tracks 53350 to 53400
# Processing tracks 53400 to 53450
# Processing tracks 53450 to 53500
# Processing tracks 53500 to 53550
# Processing tracks 53550 to 53600
# Processing tracks 53600 to 53650
# Processing tracks 53650 to 53700
# Processing tracks 53700 to 53750
# Processing tracks 53750 to 53800
# Processing tracks 53800 to 53850
# Processing tracks 53850 to 53900
# Processing tracks 53900 to 53950
# Processing tracks 53950 to 54000
# Processing tracks 54000 to 54050
# Processing tracks 54050 to 54100
# Processing tracks 54100 to 54150
# Processing tracks 54150 to 54200
# Processing tracks 54200 to 54250
# Processing tracks 54250 to 54300
# Processing tracks 54300 to 54350
# Processing tracks 54350 to 54400
# Processing tracks 54400 to 54450
# Processing tracks 54450 to 54500
# Processing tracks 54500 to 54550
# Processing tracks 54550 to 54600
# Processing tracks 54600 to 54650
# Processing tracks 54650 to 54700
# Processing tracks 54700 to 54750
# Processing tracks 54750 to 54800
# Processing tracks 54800 to 54850
# Processing tracks 54850 to 54900
# Processing tracks 54900 to 54950
# Processing tracks 54950 to 55000
# Processing tracks 55000 to 55050
# Processing tracks 55050 to 55100
# Processing tracks 55100 to 55150
# Processing tracks 55150 to 55200
# Processing tracks 55200 to 55250
# Processing tracks 55250 to 55300
# Processing tracks 55300 to 55350
# Processing tracks 55350 to 55400
# Processing tracks 55400 to 55450
# Processing tracks 55450 to 55500
# Processing tracks 55500 to 55550
# Processing tracks 55550 to 55600
# Processing tracks 55600 to 55650
# Processing tracks 55650 to 55700
# Processing tracks 55700 to 55750
# Processing tracks 55750 to 55800
# Processing tracks 55800 to 55850
# Processing tracks 55850 to 55900
# Processing tracks 55900 to 55950
# Processing tracks 55950 to 56000
# Processing tracks 56000 to 56050
# Processing tracks 56050 to 56100
# Processing tracks 56100 to 56150
# Processing tracks 56150 to 56200
# Processing tracks 56200 to 56250
# Processing tracks 56250 to 56300
# Processing tracks 56300 to 56350
# Processing tracks 56350 to 56400
# Processing tracks 56400 to 56450
# Processing tracks 56450 to 56500
# Processing tracks 56500 to 56550
# Processing tracks 56550 to 56600
# Processing tracks 56600 to 56650
# Processing tracks 56650 to 56700
# Processing tracks 56700 to 56750
# Processing tracks 56750 to 56800
# Processing tracks 56800 to 56850
# Processing tracks 56850 to 56900
# Processing tracks 56900 to 56950
# Processing tracks 56950 to 57000
# Processing tracks 57000 to 57050
# Processing tracks 57050 to 57100
# Processing tracks 57100 to 57150
# Processing tracks 57150 to 57200
# Processing tracks 57200 to 57250
# Processing tracks 57250 to 57300
# Processing tracks 57300 to 57350
# Processing tracks 57350 to 57400
# Processing tracks 57400 to 57450
# Processing tracks 57450 to 57500
# Processing tracks 57500 to 57550
# Processing tracks 57550 to 57600
# Processing tracks 57600 to 57650
# Processing tracks 57650 to 57700
# Processing tracks 57700 to 57750
# Processing tracks 57750 to 57800
# Processing tracks 57800 to 57850
# Processing tracks 57850 to 57900
# Processing tracks 57900 to 57950
# Processing tracks 57950 to 58000
# Processing tracks 58000 to 58050
# Processing tracks 58050 to 58100
# Processing tracks 58100 to 58150
# Processing tracks 58150 to 58200
# Processing tracks 58200 to 58250
# Processing tracks 58250 to 58300
# Processing tracks 58300 to 58350
# Processing tracks 58350 to 58400
# Processing tracks 58400 to 58450
# Processing tracks 58450 to 58500
# Processing tracks 58500 to 58550
# Processing tracks 58550 to 58600
# Processing tracks 58600 to 58650
# Processing tracks 58650 to 58700
# Processing tracks 58700 to 58750
# Processing tracks 58750 to 58800
# Processing tracks 58800 to 58850
# Processing tracks 58850 to 58900
# Processing tracks 58900 to 58950
# Processing tracks 58950 to 59000
# Processing tracks 59000 to 59050
# Processing tracks 59050 to 59100
# Processing tracks 59100 to 59150
# Processing tracks 59150 to 59200
# Processing tracks 59200 to 59250
# Processing tracks 59250 to 59300
# Processing tracks 59300 to 59350
# Processing tracks 59350 to 59400
# Processing tracks 59400 to 59450
# Processing tracks 59450 to 59500
# Processing tracks 59500 to 59550
# Processing tracks 59550 to 59600
# Processing tracks 59600 to 59650
# Processing tracks 59650 to 59700
# Processing tracks 59700 to 59750
# Processing tracks 59750 to 59800
# Processing tracks 59800 to 59850
# Processing tracks 59850 to 59900
# Processing tracks 59900 to 59950
# Processing tracks 59950 to 60000
# Processing tracks 60000 to 60050
# Processing tracks 60050 to 60100
# Processing tracks 60100 to 60150
# Processing tracks 60150 to 60200
# Processing tracks 60200 to 60250
# Processing tracks 60250 to 60300
# Processing tracks 60300 to 60350
# Processing tracks 60350 to 60400
# Processing tracks 60400 to 60450
# Processing tracks 60450 to 60500
# Processing tracks 60500 to 60550
# Processing tracks 60550 to 60600
# Processing tracks 60600 to 60650
# Processing tracks 60650 to 60700
# Processing tracks 60700 to 60750
# Processing tracks 60750 to 60800
# Processing tracks 60800 to 60850
# Processing tracks 60850 to 60900
# Processing tracks 60900 to 60950
# Processing tracks 60950 to 61000
# Processing tracks 61000 to 61050
# Processing tracks 61050 to 61100
# Processing tracks 61100 to 61150
# Processing tracks 61150 to 61200
# Processing tracks 61200 to 61250
# Processing tracks 61250 to 61300
# Processing tracks 61300 to 61350
# Processing tracks 61350 to 61400
# Processing tracks 61400 to 61450
# Processing tracks 61450 to 61500
# Processing tracks 61500 to 61550
# Processing tracks 61550 to 61600
# Processing tracks 61600 to 61650
# Processing tracks 61650 to 61700
# Processing tracks 61700 to 61750
# Processing tracks 61750 to 61800
# Processing tracks 61800 to 61850
# Processing tracks 61850 to 61900
# Processing tracks 61900 to 61950
# Processing tracks 61950 to 62000
# Processing tracks 62000 to 62050
# Processing tracks 62050 to 62100
# Processing tracks 62100 to 62150
# Processing tracks 62150 to 62200
# Processing tracks 62200 to 62250
# Processing tracks 62250 to 62300
# Processing tracks 62300 to 62350
# Processing tracks 62350 to 62400
# Processing tracks 62400 to 62450
# Processing tracks 62450 to 62500
# Processing tracks 62500 to 62550
# Processing tracks 62550 to 62600
# Processing tracks 62600 to 62650
# Processing tracks 62650 to 62700
# Processing tracks 62700 to 62750
# Processing tracks 62750 to 62800
# Processing tracks 62800 to 62850
# Processing tracks 62850 to 62900
# Processing tracks 62900 to 62950
# Processing tracks 62950 to 63000
# Processing tracks 63000 to 63050
# Processing tracks 63050 to 63100
# Processing tracks 63100 to 63150
# Processing tracks 63150 to 63200
# Processing tracks 63200 to 63250
# Processing tracks 63250 to 63300
# Processing tracks 63300 to 63350
# Processing tracks 63350 to 63400
# Processing tracks 63400 to 63450
# Processing tracks 63450 to 63500
# Processing tracks 63500 to 63550
# Processing tracks 63550 to 63600
# Processing tracks 63600 to 63650
# Processing tracks 63650 to 63700
# Processing tracks 63700 to 63750
# Error processing tracks 63700 to 63750
# Processing tracks 63750 to 63800
# Processing tracks 63800 to 63850
# Processing tracks 63850 to 63900
# Processing tracks 63900 to 63950
# Processing tracks 63950 to 64000
# Processing tracks 64000 to 64050
# Processing tracks 64050 to 64100
# Processing tracks 64100 to 64150
# Processing tracks 64150 to 64200
# Processing tracks 64200 to 64250
# Processing tracks 64250 to 64300
# Processing tracks 64300 to 64350
# Processing tracks 64350 to 64400
# Processing tracks 64400 to 64450
# Processing tracks 64450 to 64500
# Processing tracks 64500 to 64550
# Processing tracks 64550 to 64600
# Processing tracks 64600 to 64650
# Processing tracks 64650 to 64700
# Processing tracks 64700 to 64750
# Processing tracks 64750 to 64800
# Processing tracks 64800 to 64850
# Processing tracks 64850 to 64900
# Processing tracks 64900 to 64950
# Processing tracks 64950 to 65000
# Processing tracks 65000 to 65050
# Processing tracks 65050 to 65100
# Processing tracks 65100 to 65150
# Processing tracks 65150 to 65200
# Processing tracks 65200 to 65250
# Processing tracks 65250 to 65300
# Processing tracks 65300 to 65350
# Processing tracks 65350 to 65400
# Processing tracks 65400 to 65450
# Processing tracks 65450 to 65500
# Processing tracks 65500 to 65550
# Processing tracks 65550 to 65600
# Processing tracks 65600 to 65650
# Processing tracks 65650 to 65700
# Processing tracks 65700 to 65750
# Processing tracks 65750 to 65800
# Processing tracks 65800 to 65850
# Processing tracks 65850 to 65900
# Processing tracks 65900 to 65950
# Processing tracks 65950 to 66000
# Processing tracks 66000 to 66050
# Processing tracks 66050 to 66100
# Processing tracks 66100 to 66150
# Processing tracks 66150 to 66200
# Processing tracks 66200 to 66250
# Processing tracks 66250 to 66300
# Processing tracks 66300 to 66350
# Processing tracks 66350 to 66400
# Processing tracks 66400 to 66450
# Processing tracks 66450 to 66500
# Processing tracks 66500 to 66550
# Processing tracks 66550 to 66600
# Processing tracks 66600 to 66650
# Processing tracks 66650 to 66700
# Processing tracks 66700 to 66750
# Processing tracks 66750 to 66800
# Processing tracks 66800 to 66850
# Processing tracks 66850 to 66900
# Processing tracks 66900 to 66950
# Processing tracks 66950 to 67000
# Processing tracks 67000 to 67050
# Processing tracks 67050 to 67100
# Processing tracks 67100 to 67150
# Processing tracks 67150 to 67200
# Processing tracks 67200 to 67250
# Processing tracks 67250 to 67300
# Processing tracks 67300 to 67350
# Processing tracks 67350 to 67400
# Processing tracks 67400 to 67450
# Processing tracks 67450 to 67500
# Processing tracks 67500 to 67550
# Processing tracks 67550 to 67600
# Processing tracks 67600 to 67650
# Processing tracks 67650 to 67700
# Processing tracks 67700 to 67750
# Processing tracks 67750 to 67800
# Processing tracks 67800 to 67850
# Processing tracks 67850 to 67900
# Error processing tracks 67850 to 67900
# Processing tracks 67900 to 67950
# Processing tracks 67950 to 68000
# Processing tracks 68000 to 68050
# Processing tracks 68050 to 68100
# Processing tracks 68100 to 68150
# Processing tracks 68150 to 68200
# Processing tracks 68200 to 68250
# Processing tracks 68250 to 68300
# Processing tracks 68300 to 68350
# Processing tracks 68350 to 68400
# Processing tracks 68400 to 68450
# Processing tracks 68450 to 68500
# Processing tracks 68500 to 68550
# Processing tracks 68550 to 68600
# Processing tracks 68600 to 68650
# Processing tracks 68650 to 68700
# Processing tracks 68700 to 68750
# Processing tracks 68750 to 68800
# Processing tracks 68800 to 68850
# Processing tracks 68850 to 68900
# Processing tracks 68900 to 68950
# Processing tracks 68950 to 69000
# Processing tracks 69000 to 69050
# Processing tracks 69050 to 69100
# Processing tracks 69100 to 69150
# Processing tracks 69150 to 69200
# Processing tracks 69200 to 69250
# Processing tracks 69250 to 69300
# Processing tracks 69300 to 69350
# Processing tracks 69350 to 69400
# Processing tracks 69400 to 69450
# Processing tracks 69450 to 69500
# Processing tracks 69500 to 69550
# Processing tracks 69550 to 69600
# Processing tracks 69600 to 69650
# Processing tracks 69650 to 69700
# Processing tracks 69700 to 69750
# Processing tracks 69750 to 69800
# Processing tracks 69800 to 69850
# Processing tracks 69850 to 69900
# Processing tracks 69900 to 69950
# Processing tracks 69950 to 70000
# Processing tracks 70000 to 70050
# Processing tracks 70050 to 70100
# Processing tracks 70100 to 70150
# Processing tracks 70150 to 70200
# Processing tracks 70200 to 70250
# Processing tracks 70250 to 70300
# Processing tracks 70300 to 70350
# Processing tracks 70350 to 70400
# Processing tracks 70400 to 70450
# Processing tracks 70450 to 70500
# Processing tracks 70500 to 70550
# Processing tracks 70550 to 70600
# Processing tracks 70600 to 70650
# Processing tracks 70650 to 70700
# Processing tracks 70700 to 70750
# Processing tracks 70750 to 70800
# Processing tracks 70800 to 70850
# Processing tracks 70850 to 70900
# Processing tracks 70900 to 70950
# Processing tracks 70950 to 71000
# Processing tracks 71000 to 71050
# Processing tracks 71050 to 71100
# Processing tracks 71100 to 71150
# Processing tracks 71150 to 71200
# Processing tracks 71200 to 71250
# Processing tracks 71250 to 71300
# Processing tracks 71300 to 71350
# Processing tracks 71350 to 71400
# Processing tracks 71400 to 71450
# Processing tracks 71450 to 71500
# Processing tracks 71500 to 71550
# Processing tracks 71550 to 71600
# Processing tracks 71600 to 71650
# Processing tracks 71650 to 71700
# Processing tracks 71700 to 71750
# Processing tracks 71750 to 71800
# Processing tracks 71800 to 71850
# Processing tracks 71850 to 71900
# Processing tracks 71900 to 71950
# Processing tracks 71950 to 72000
# Processing tracks 72000 to 72050
# Processing tracks 72050 to 72100
# Processing tracks 72100 to 72150
# Processing tracks 72150 to 72200
# Processing tracks 72200 to 72250
# Processing tracks 72250 to 72300
# Processing tracks 72300 to 72350
# Processing tracks 72350 to 72400
# Processing tracks 72400 to 72450
# Processing tracks 72450 to 72500
# Processing tracks 72500 to 72550
# Processing tracks 72550 to 72600
# Processing tracks 72600 to 72650
# Processing tracks 72650 to 72700
# Processing tracks 72700 to 72750
# Processing tracks 72750 to 72800
# Processing tracks 72800 to 72850
# Processing tracks 72850 to 72900
# Processing tracks 72900 to 72950
# ...
# Error processing tracks 103100 to 103150
# Processing tracks 103150 to 103200
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103150 to 103200
# Processing tracks 103200 to 103250
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103200 to 103250
# Processing tracks 103250 to 103300
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103250 to 103300
# Processing tracks 103300 to 103350
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103300 to 103350
# Processing tracks 103350 to 103400
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103350 to 103400
# Processing tracks 103400 to 103450
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103400 to 103450
# Processing tracks 103450 to 103500
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103450 to 103500
# Processing tracks 103500 to 103550
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103500 to 103550
# Processing tracks 103550 to 103600
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103550 to 103600
# Processing tracks 103600 to 103650
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103600 to 103650
# Processing tracks 103650 to 103700
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103650 to 103700
# Processing tracks 103700 to 103750
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103700 to 103750
# Processing tracks 103750 to 103800
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103750 to 103800
# Processing tracks 103800 to 103850
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103800 to 103850
# Processing tracks 103850 to 103900
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103850 to 103900
# Processing tracks 103900 to 103950
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103900 to 103950
# Processing tracks 103950 to 104000
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 103950 to 104000
# Processing tracks 104000 to 104050
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104000 to 104050
# Processing tracks 104050 to 104100
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104050 to 104100
# Processing tracks 104100 to 104150
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104100 to 104150
# Processing tracks 104150 to 104200
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104150 to 104200
# Processing tracks 104200 to 104250
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104200 to 104250
# Processing tracks 104250 to 104300
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104250 to 104300
# Processing tracks 104300 to 104350
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104300 to 104350
# Processing tracks 104350 to 104400
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104350 to 104400
# Processing tracks 104400 to 104450
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104400 to 104450
# Processing tracks 104450 to 104500
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104450 to 104500
# Processing tracks 104500 to 104550
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104500 to 104550
# Processing tracks 104550 to 104600
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104550 to 104600
# Processing tracks 104600 to 104650
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104600 to 104650
# Processing tracks 104650 to 104700
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104650 to 104700
# Processing tracks 104700 to 104750
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104700 to 104750
# Processing tracks 104750 to 104800
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104750 to 104800
# Processing tracks 104800 to 104850
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104800 to 104850
# Processing tracks 104850 to 104900
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104850 to 104900
# Processing tracks 104900 to 104950
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104900 to 104950
# Processing tracks 104950 to 105000
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 104950 to 105000
# Processing tracks 105000 to 105050
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105000 to 105050
# Processing tracks 105050 to 105100
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105050 to 105100
# Processing tracks 105100 to 105150
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105100 to 105150
# Processing tracks 105150 to 105200
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105150 to 105200
# Processing tracks 105200 to 105250
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105200 to 105250
# Processing tracks 105250 to 105300
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105250 to 105300
# Processing tracks 105300 to 105350
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105300 to 105350
# Processing tracks 105350 to 105400
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105350 to 105400
# Processing tracks 105400 to 105450
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105400 to 105450
# Processing tracks 105450 to 105500
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105450 to 105500
# Processing tracks 105500 to 105550
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105500 to 105550
# Processing tracks 105550 to 105600
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105550 to 105600
# Processing tracks 105600 to 105650
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105600 to 105650
# Processing tracks 105650 to 105700
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105650 to 105700
# Processing tracks 105700 to 105750
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105700 to 105750
# Processing tracks 105750 to 105800
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105750 to 105800
# Processing tracks 105800 to 105850
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105800 to 105850
# Processing tracks 105850 to 105900
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105850 to 105900
# Processing tracks 105900 to 105950
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105900 to 105950
# Processing tracks 105950 to 106000
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 105950 to 106000
# Processing tracks 106000 to 106050
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106000 to 106050
# Processing tracks 106050 to 106100
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106050 to 106100
# Processing tracks 106100 to 106150
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106100 to 106150
# Processing tracks 106150 to 106200
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106150 to 106200
# Processing tracks 106200 to 106250
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106200 to 106250
# Processing tracks 106250 to 106300
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106250 to 106300
# Processing tracks 106300 to 106350
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106300 to 106350
# Processing tracks 106350 to 106400
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106350 to 106400
# Processing tracks 106400 to 106450
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106400 to 106450
# Processing tracks 106450 to 106500
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106450 to 106500
# Processing tracks 106500 to 106550
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106500 to 106550
# Processing tracks 106550 to 106600
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106550 to 106600
# Processing tracks 106600 to 106650
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106600 to 106650
# Processing tracks 106650 to 106700
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106650 to 106700
# Processing tracks 106700 to 106750
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106700 to 106750
# Processing tracks 106750 to 106800
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106750 to 106800
# Processing tracks 106800 to 106850
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106800 to 106850
# Processing tracks 106850 to 106900
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106850 to 106900
# Processing tracks 106900 to 106950
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106900 to 106950
# Processing tracks 106950 to 107000
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 106950 to 107000
# Processing tracks 107000 to 107050
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107000 to 107050
# Processing tracks 107050 to 107100
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107050 to 107100
# Processing tracks 107100 to 107150
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107100 to 107150
# Processing tracks 107150 to 107200
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107150 to 107200
# Processing tracks 107200 to 107250
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107200 to 107250
# Processing tracks 107250 to 107300
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107250 to 107300
# Processing tracks 107300 to 107350
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107300 to 107350
# Processing tracks 107350 to 107400
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107350 to 107400
# Processing tracks 107400 to 107450
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107400 to 107450
# Processing tracks 107450 to 107500
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107450 to 107500
# Processing tracks 107500 to 107550
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107500 to 107550
# Processing tracks 107550 to 107600
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107550 to 107600
# Processing tracks 107600 to 107650
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107600 to 107650
# Processing tracks 107650 to 107700
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107650 to 107700
# Processing tracks 107700 to 107750
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107700 to 107750
# Processing tracks 107750 to 107800
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107750 to 107800
# Processing tracks 107800 to 107850
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107800 to 107850
# Processing tracks 107850 to 107900
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107850 to 107900
# Processing tracks 107900 to 107950
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107900 to 107950
# Processing tracks 107950 to 108000
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 107950 to 108000
# Processing tracks 108000 to 108050
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 108000 to 108050
# Processing tracks 108050 to 108100
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 108050 to 108100
# Processing tracks 108100 to 108150
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 108100 to 108150
# Processing tracks 108150 to 108200
# Erro: 401
# Erro: {'error': {'status': 401, 'message': 'The access token expired'}}
# Error processing tracks 108150 to 108200
